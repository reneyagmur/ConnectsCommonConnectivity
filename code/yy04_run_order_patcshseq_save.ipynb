# %% [markdown]
# # Run order of * patschseq * related notebooks
# 1. patchseq_and_wnm_datasets.ipynb -> __dataitem, dataset, dataitem_dataset_association__
# 2. process_patchseq_taxonomy_info.ipynb --> __cluster__
# 3. patchseq_morph_features.ipynb --> __cellfeatures, cellfeatureset, cellfeaturedefinitions__
# 4. patchseq_type_mapping.ipynb --> __cluster membership__
# 5. Make and color patchseq and wnm umap.ipynb --> __plotting__
